# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python -m pip uninstall -y talk-tag
# !python -m pip install "git+https://github.com/OliverHennhoefer/talk-tag.git"
# Out:
# WARNING: Skipping talk-tag as it is not installed.
# ...
#   Cloning https://github.com/OliverHennhoefer/talk-tag.git to /tmp/pip-req-build-csp6dk5p
#   Running command git clone --filter=blob:none --quiet https://github.com/OliverHennhoefer/talk-tag.git /tmp/pip-req-build-csp6dk5p
#   Resolved https://github.com/OliverHennhoefer/talk-tag.git to commit ccbf828d1cfe6591c72a8f791e19c53875e3f878
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 199.8 MB/s eta 0:00:00
# ...
#   Created wheel for talk-tag: filename=talk_tag-0.4.0-py3-none-any.whl size=33485 sha256=dafa4c204c895d35b1ce23dac8b1932fedab197622e14fbe899342296cbf8d15
#   Stored in directory: /tmp/pip-ephem-wheel-cache-03v1mzs0/wheels/0d/ef/c0/a1dcee92fed4ba1d3df08345c8be4bb2ca71e27bc12caedf1c
# ...

# %%
from google.colab import userdata
import os

os.environ["GITHUB_TOKEN"] = userdata.get("GITHUB_TOKEN")

# %%
#!pip install --no-cache-dir "git+https://YOUR_GITHUB_USERNAME:${GITHUB_TOKEN}@github.com/OliverHennhoefer/talk-tag.git@feat/clan-output-normalization"

# %%
# !pip install -U bitsandbytes>=0.46.1

# %%
import talk_tag

# %%
# !python -m talk_tag.cli annotate \
  --input-dir /content/drive/MyDrive/ColabNotebooks/stage2_sli \
  --output-dir /content/drive/MyDrive/ColabNotebooks/stage2_sli_annotated \
  --target-speaker "*CHI" \
  --speaker-field speaker \
  --text-field utterance \
  --limit 0
# Out:
# Streaming output truncated to the last 5000 lines.
# pair_sli475_td417_rep03_B3_SLI.cha:lines:  23% 17/74 [00:00<00:00, 86.68it/s]
# pair_sli475_td417_rep03_B3_SLI.cha:lines:  35% 26/74 [00:00<00:01, 25.79it/s]
# pair_sli475_td417_rep03_B3_SLI.cha:lines:  42% 31/74 [00:01<00:01, 26.71it/s]
# pair_sli475_td417_rep03_B3_SLI.cha:lines:  47% 35/74 [00:01<00:02, 13.27it/s]
# pair_sli475_td417_rep03_B3_SLI.cha:lines:  51% 38/74 [00:02<00:02, 12.38it/s]
# pair_sli475_td417_rep03_B3_SLI.cha:lines:  55% 41/74 [00:02<00:03, 10.64it/s]
# pair_sli475_td417_rep03_B3_SLI.cha:lines:  59% 44/74 [00:02<00:03,  9.93it/s]
# pair_sli475_td417_rep03_B3_SLI.cha:lines:  64% 47/74 [00:03<00:02, 10.11it/s]
# pair_sli475_td417_rep03_B3_SLI.cha:lines:  68% 50/74 [00:03<00:02, 10.25it/s]
# pair_sli475_td417_rep03_B3_SLI.cha:lines:  72% 53/74 [00:04<00:02,  8.13it/s]
# pair_sli475_td417_rep03_B3_SLI.cha:lines:  76% 56/74 [00:04<00:02,  7.97it/s]
# ...
